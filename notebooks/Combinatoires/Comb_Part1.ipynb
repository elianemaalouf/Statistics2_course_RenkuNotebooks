# %%
import ipywidgets as widgets
import fn as fn 
from IPython.display import display, clear_output, Image
import asyncio

# %% [markdown]
# Pour chacun des exercices ci-dessous vous pouvez directement donner votre réponse et valider si elle est correcte ou vous pouvez procéder à résoudre les questions étape par étape pour décortiquer l'intuition qui se cache derrière la solution.

# %% [markdown]
# # Rappel
#
# ## Principe de multiplication
# Supposons qu’une épreuve puisse se décomposer en $𝑘$ opérations élémentaires **successives**.
# Si ces opérations peuvent s’effectuer respectivement de $𝑛_1$, $𝑛_2$, …, $𝑛_𝑘$ manières différentes, alors l’épreuve peut se réaliser de $𝑛_1 \times 𝑛_2 \times… \times 𝑛_𝑘$ manières différentes.
#
#
# ## Principe d'addition
# Supposons qu’une épreuve puisse se décomposer en $𝑘$ opérations élémentaires mutuellement **exclusives**.
# Si ces dernières peuvent s’effectuer respectivement de $𝑛_1$, $𝑛_2$, …, $𝑛_𝑘$ manières différentes, alors l’épreuve peut se réaliser de $𝑛_1+𝑛_2+⋯+𝑛_𝑘$ manières différentes.

# %% [markdown]
# # Exercice 1
# De combien de façons peut-on répondre à un QCM composé de 10 questions, s’il y a 5 suggestions à chaque question, et qu’il n’est possible d’en choisir qu’une seule par question ?

# %%
n_ex1 = 10 # nombre de questions 
n_choice_ex1 = 5 # nombre de choix par question

counter_1_ex1 = 0

ex1_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)


def test_0_ex1(change):
    global counter_1_ex1 
    counter_1_ex1 = counter_1_ex1 + 1
    value = ex1_answer.value
    correct_value = fn.verify_ex1(n_ex1, n_choice_ex1)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_1_ex1))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Vous pouvez resoumettre une autre réponse ou procéder étape par étape en cliquant sur 'Show Solution'".format(counter_1_ex1))


display(widgets.HBox([ex1_answer, button]))

button.on_click(test_0_ex1)
    
#print(fn.verify_ex1(n, n_choice))
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Penser à ce QCM comme une série de 10 opérations successives. \n  ")
print("De combien de manières peut on effectuer la première opération? \n Dit autrement, de combien de manières différentes peut on répondre à la question 1:")

def test_1_ex1(change):
    global counter_2_ex1 
    counter_2_ex1 = counter_2_ex1 + 1
    value = q1_answer.value
    correct_value = n_choice_ex1
    if value == correct_value:
        display("Tentative {} : Exact!!".format(counter_2_ex1))
    else:
        display("Tentative {}: Essayez encore! hint: combien de choix possible a-t-on par question?".format(counter_2_ex1))

counter_2_ex1 = 0
q1_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)
button_q1 = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)


display(widgets.HBox([q1_answer, button_q1]))

out1 = widgets.Output(layout={'border': '1px solid black'})

with out1:
    button_q1.on_click(test_1_ex1)
out1
# Out:
# Penser à ce QCM comme une série de 10 opérations successives.
#
# De combien de manières peut on effectuer la première opération?
#  Dit autrement, de combien de manières différentes peut on répondre à la question 1:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…
# Output(layout=Layout(border='1px solid black'))

# %%
print("ET \n")

print("De combien de mainières différentes peut on répondre à la question 2: \n")

def test_2_ex1(change):
    global counter_3_ex1 
    counter_3_ex1 = counter_3_ex1 + 1
    value = q2_answer.value
    correct_value = n_choice_ex1
    if value == correct_value:
        display("Tentative {} : Exact!!".format(counter_3_ex1))
    else:
        display("Tentative {}: Essayez encore! hint: combien de choix possible a-t-on par question?".format(counter_3_ex1))

    
counter_3_ex1 = 0
q2_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)
button_q2 = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


display(widgets.HBox([q2_answer, button_q2]))

out2 = widgets.Output(layout={'border': '1px solid black'})

with out2:
    button_q2.on_click(test_2_ex1)
out2
# Out:
# ET
#
# De combien de mainières différentes peut on répondre à la question 2:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…
# Output(layout=Layout(border='1px solid black'))

# %%
print("ET ... \n")

print("de la même manière chaque question aura 5 manières différentes pour y répondre. \n")

print("Une fois on a fait la réflexion pour chaque question, on doit combiner le tout. Comment faire? \n")
print("Quel principe faudra-t-il appliquer ici pour combiner?")

def test_3_ex2(change):
    global counter_4_ex1 
    counter_4_ex1 = counter_4_ex1 + 1
    value = drop_ex1.value
    correct_value = 'multiplication'
    if value == correct_value:
        print("Tentative {counter} : Exact! Nous devons procéder à multiplier {n_choice} par lui-même {n} fois. \n \
        Revenez au début de l'exercice et resoumettez votre réponse. \n\
        Un exemple détaillé se trouve ci-dessous."
              .format(counter = counter_4_ex1, n_choice= n_choice_ex1, n = n_ex1))
    else:

        print("Tentative {counter}: Non, ce n'est pas tout à fait correct. \n \
        Regardez l'exemple détaillé ci-dessous.".format(counter=counter_4_ex1))

counter_4_ex1 = 0
drop_ex1 = widgets.Dropdown(
    options=['aucune', 'addition', 'multiplication', 'les deux'],
    value='aucune',
    description='Principe de:',
    disabled=False,
)

button_comb = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)

display(widgets.HBox([drop_ex1, button_comb]))

out3 = widgets.Output(layout={'border': '1px solid black'})

with out3:
    button_comb.on_click(test_3_ex2)
out3
# Out:
# ET ...
#
# de la même manière chaque question aura 5 manières différentes pour y répondre.
#
# Une fois on a fait la réflexion pour chaque question, on doit combiner le tout. Comment faire?
#
# Quel principe faudra-t-il appliquer ici pour combiner?
# HBox(children=(Dropdown(description='Principe de:', options=('aucune', 'addition', 'multiplication', 'les deux…
# Output(layout=Layout(border='1px solid black'))

# %% [raw]
# <svg height="500" width="100%"><desc>Created with Snap</desc><defs><filter id="Skzda3o053" filterUnits="userSpaceOnUse"><feGaussianBlur in="SourceAlpha" stdDeviation="3"></feGaussianBlur><feOffset dx="0" dy="2" result="offsetblur"></feOffset><feFlood flood-color="#000000"></feFlood><feComposite in2="offsetblur" operator="in"></feComposite><feComponentTransfer><feFuncA type="linear" slope="1"></feFuncA></feComponentTransfer><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><marker viewBox="0 0 10 10" markerWidth="10" markerHeight="10" orient="auto" refX="9" refY="3" id="arrowEndMarker"><polygon points="0,0,0,6,9,3,0,0" fill="#323232" id="arrow" style=""></polygon></marker><marker viewBox="0 0 10 10" markerWidth="10" markerHeight="10" orient="auto" refX="0" refY="3" id="arrowStartMarker"><polygon points="0,3,9,0,9,6,0,3" fill="#323232" id="startArrow" style=""></polygon></marker><filter id="Skzdzwz6p3" filterUnits="userSpaceOnUse"><feGaussianBlur in="SourceAlpha" stdDeviation="3"></feGaussianBlur><feOffset dx="0" dy="2" result="offsetblur"></feOffset><feFlood flood-color="#000000"></feFlood><feComposite in2="offsetblur" operator="in"></feComposite><feComponentTransfer><feFuncA type="linear" slope="1"></feFuncA></feComponentTransfer><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><marker viewBox="0 0 10 10" markerWidth="10" markerHeight="10" orient="auto" refX="9" refY="3" id="arrowEndMarker"><polygon points="0,0,0,6,9,3,0,0" fill="#323232" id="arrow" style=""></polygon></marker><marker viewBox="0 0 10 10" markerWidth="10" markerHeight="10" orient="auto" refX="0" refY="3" id="arrowStartMarker"><polygon points="0,3,9,0,9,6,0,3" fill="#323232" id="startArrow" style=""></polygon></marker><filter id="Skzvsarbi3" filterUnits="userSpaceOnUse"><feGaussianBlur in="SourceAlpha" stdDeviation="3"></feGaussianBlur><feOffset dx="0" dy="2" result="offsetblur"></feOffset><feFlood flood-color="#000000"></feFlood><feComposite in2="offsetblur" operator="in"></feComposite><feComponentTransfer><feFuncA type="linear" slope="1"></feFuncA></feComponentTransfer><feMerge><feMergeNode></feMergeNode><feMergeNode in="SourceGraphic"></feMergeNode></feMerge></filter><marker viewBox="0 0 10 10" markerWidth="10" markerHeight="10" orient="auto" refX="9" refY="3" id="arrowEndMarker"><polygon points="0,0,0,6,9,3,0,0" fill="#323232" id="arrow" style=""></polygon></marker><marker viewBox="0 0 10 10" markerWidth="10" markerHeight="10" orient="auto" refX="0" refY="3" id="arrowStartMarker"><polygon points="0,3,9,0,9,6,0,3" fill="#323232" id="startArrow" style=""></polygon></marker></defs><g id="drup_elem_23" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 1 1" transform="matrix(1,0,0,1,9,101)">1 1 1</text></g><g id="drup_elem_43" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 2 1" transform="matrix(1,0,0,1,121,98)">1 2 1</text></g><g id="drup_elem_46" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 3 1" transform="matrix(1,0,0,1,229,98)">1 3 1</text></g><g id="drup_elem_24" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 1 2" transform="matrix(1,0,0,1,6,124)">1 1 2</text></g><g id="drup_elem_44" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 2 2" transform="matrix(1,0,0,1,122,127)">1 2 2</text></g><g id="drup_elem_47" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 3 2" transform="matrix(1,0,0,1,230,127)">1 3 2</text></g><g id="drup_elem_25" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 1 3" transform="matrix(1,0,0,1,6,151)">1 1 3</text></g><g id="drup_elem_45" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 2 3" transform="matrix(1,0,0,1,123,154)">1 2 3</text></g><g id="drup_elem_48" first-frame="1" last-frame="1" class="drupElem"><text x="53.067718505859375" y="71.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="1 3 3" transform="matrix(1,0,0,1,231,154)">1 3 3</text></g><g id="drup_elem_3" first-frame="1" last-frame="1" class="drupElem"><text x="379.0677185058594" y="87.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_4" first-frame="1" last-frame="1" class="drupElem"><text x="437.0677185058594" y="182.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_5" first-frame="1" last-frame="1" class="drupElem"><text x="51.067718505859375" y="63.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="Pour ne pas encombrer la présentation supposons qu'il y a seulement 3 questions et 3 choix par question" transform="matrix(1,0,0,1,435,-19)">Pour ne pas encombrer la présentation supposons qu'il y a seulement 3 questions et 3 choix par question</text></g><g id="drup_elem_10" first-frame="1" last-frame="1" class="drupElem"><text x="655.0677185058594" y="169.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_11" first-frame="1" last-frame="1" class="drupElem"><text x="619.0677185058594" y="109.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_12" first-frame="1" last-frame="1" class="drupElem"><text x="434.0677185058594" y="128.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_13" first-frame="1" last-frame="1" class="drupElem"><text x="430.0677185058594" y="134.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_21" first-frame="1" last-frame="1" class="drupElem"><text x="318.0677185058594" y="193.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_33" first-frame="1" last-frame="1" class="drupElem"><text x="381.0677185058594" y="180.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="Ci-dessous est une liste de toutes les manières possibles de répondre à ce QCM" transform="matrix(1,0,0,1,-3,-113)">Ci-dessous est une liste de toutes les manières possibles de répondre à ce QCM</text></g><g id="drup_elem_34" first-frame="1" last-frame="1" class="drupElem"><text x="269.0677185058594" y="167.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="Chaque triple représente une possibilité de réponse au QCM. " transform="matrix(1,0,0,1,22,-76)">Chaque triple représente une possibilité de réponse au QCM. </text></g><g id="drup_elem_35" first-frame="1" last-frame="1" class="drupElem"><text x="269.0677185058594" y="186.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_36" first-frame="1" last-frame="1" class="drupElem"><text x="540.0677185058594" y="89.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_37" first-frame="1" last-frame="1" class="drupElem"><text x="541.0677185058594" y="231.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_38" first-frame="1" last-frame="1" class="drupElem"><text x="361.0677185058594" y="233.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="Par exemple: le triple 1 3 2 sera la réponse 1 à la question 1, la réponse 3 à la question 2 " transform="matrix(1,0,0,1,53,-119)">Par exemple: le triple 1 3 2 sera la réponse 1 à la question 1, la réponse 3 à la question 2 </text></g><g id="drup_elem_39" first-frame="1" last-frame="1" class="drupElem"><text x="341.0677185058594" y="240.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_40" first-frame="1" last-frame="1" class="drupElem"><text x="368.0677185058594" y="246.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_41" first-frame="1" last-frame="1" class="drupElem"><text x="368.0677185058594" y="216.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="et la réponse 2 à la question 3" transform="matrix(1,0,0,1,-215,-80)">et la réponse 2 à la question 3</text></g><g id="drup_elem_42" first-frame="1" last-frame="1" class="drupElem"><text x="215.06771850585938" y="109.66927146911621" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_49" first-frame="1" last-frame="1" class="drupElem"><text x="40.067718505859375" y="278.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 1 1" transform="matrix(1,0,0,1,19,0)">2 1 1</text></g><g id="drup_elem_53" first-frame="1" last-frame="1" class="drupElem"><text x="40.067718505859375" y="278.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="2 1 2" transform="matrix(1,0,0,1,19,25)">2 1 2</text></g><g id="drup_elem_54" first-frame="1" last-frame="1" class="drupElem"><text x="40.067718505859375" y="278.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="2 1 3" transform="matrix(1,0,0,0.8667,19,93.6559)">2 1 3</text></g><g id="drup_elem_50" first-frame="1" last-frame="1" class="drupElem"><text x="33.067718505859375" y="279.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_51" first-frame="1" last-frame="1" class="drupElem"><text x="56.067718505859375" y="292.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_52" first-frame="1" last-frame="1" class="drupElem"><text x="101.06771850585938" y="361.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_55" first-frame="1" last-frame="1" class="drupElem"><text x="147.06771850585938" y="291.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 2 1" transform="matrix(1,0,0,1,23,-13)">2 2 1</text></g><g id="drup_elem_56" first-frame="1" last-frame="1" class="drupElem"><text x="157.06771850585938" y="319.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 2 2" transform="matrix(1,0,0,1,12,-15)">2 2 2</text></g><g id="drup_elem_57" first-frame="1" last-frame="1" class="drupElem"><text x="154.06771850585938" y="369.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 2 3" transform="matrix(1,0,0,1,15,-36)">2 2 3</text></g><g id="drup_elem_58" first-frame="1" last-frame="1" class="drupElem"><text x="265.0677185058594" y="290.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 3 1" transform="matrix(1,0,0,1,17,-10)">2 3 1</text></g><g id="drup_elem_59" first-frame="1" last-frame="1" class="drupElem"><text x="262.0677185058594" y="363.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 3 2" transform="matrix(1,0,0,1,20,-60)">2 3 2</text></g><g id="drup_elem_60" first-frame="1" last-frame="1" class="drupElem"><text x="339.0677185058594" y="365.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="2 3 3" transform="matrix(1,0,0,1,-57,-33)">2 3 3</text></g><g id="drup_elem_61" first-frame="1" last-frame="1" class="drupElem"><text x="461.0677185058594" y="272.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 1 1" transform="matrix(1,0,0,1,-396,113)">3 1 1</text></g><g id="drup_elem_62" first-frame="1" last-frame="1" class="drupElem egal-select"><text x="450.0677185058594" y="320.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 1 2" transform="matrix(1,0,0,1,-385,94)">3 1 2</text></g><g id="drup_elem_63" first-frame="1" last-frame="1" class="drupElem"><text x="445.0677185058594" y="385.6692714691162" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 1 3" transform="matrix(1,0,0,1,-379,61)">3 1 3</text></g><g id="drup_elem_64" first-frame="1" last-frame="1" class="drupElem"><text x="464.0677185058594" y="301.00260734558105" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_65" first-frame="1" last-frame="1" class="drupElem"><text x="461.0677185058594" y="258.00260734558105" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_66" first-frame="1" last-frame="1" class="drupElem"><text x="602.0677185058594" y="250.3359432220459" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g><g id="drup_elem_67" first-frame="1" last-frame="1" class="drupElem"><text x="373.0677185058594" y="437.3359432220459" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 2 1" transform="matrix(1,0,0,1,-203,-52)">3 2 1</text></g><g id="drup_elem_68" first-frame="1" last-frame="1" class="drupElem"><text x="359.0677185058594" y="485.3359432220459" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 2 2" transform="matrix(1,0,0,1,-190,-71)">3 2 2</text></g><g id="drup_elem_69" first-frame="1" last-frame="1" class="drupElem"><text x="190.06771850585938" y="473.0026149749756" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 2 3" transform="matrix(1,0,0,1,-22,-28)">3 2 3</text></g><g id="drup_elem_70" first-frame="1" last-frame="1" class="drupElem"><text x="258.0677185058594" y="397.0026149749756" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 3 1" transform="matrix(1,0,0,1,20,-10)">3 3 1</text></g><g id="drup_elem_71" first-frame="1" last-frame="1" class="drupElem"><text x="269.0677185058594" y="460.0026149749756" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 3 2" transform="matrix(1,0,0,1,9,-47)">3 3 2</text></g><g id="drup_elem_72" first-frame="1" last-frame="1" class="drupElem"><text x="276.0677185058594" y="465.0026149749756" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;" data-src="3 3 3" transform="matrix(1,0,0,1,1,-21)">3 3 3</text></g><g id="drup_elem_73" first-frame="1" last-frame="1" class="drupElem"><text x="45.067718505859375" y="504.0026035308838" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 0;" transform="matrix(0.9837,0,0,1,747.7348,-23)">|</text></g><g id="drup_elem_74" first-frame="1" last-frame="1" class="drupElem"><text x="378.0677185058594" y="496.33593559265137" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px; visibility: visible; opacity: 1;" data-src="Il y a 27 possibilités, equivalent à 3 x 3 x3" transform="matrix(1,0,0,1,220,-22)">Il y a 27 possibilités, equivalent à 3 x 3 x3</text></g><g id="drup_elem_75" first-frame="1" last-frame="1" class="drupElem"><text x="343.0677185058594" y="43.502614974975586" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central;"></text></g><g id="drup_elem_76" first-frame="1" last-frame="1" class="drupElem"><text x="343.0677185058594" y="63.502614974975586" class="core alignable sub egal-label" style="text-anchor: middle; alignment-baseline: central; font-size: 20px;"></text></g></svg>

# %% [markdown]
# # Exercice 2
# Un marchand de glaces propose à ses clients une palette de 10 arômes différents et la possibilité de choisir une glace selon un agencement à une, deux ou trois boules. Combien de glaces différentes le marchand propose-t-il si une glace ne peut pas comporter deux boules du même arôme ?

# %%
n_aromes = 10
agencements = [1,2,3]
counter_1_ex2 = 0

ex2_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='',
    tooltip='Click me',
    icon='check' 
)


def test_0_ex2(change):
    global counter_1_ex2 
    counter_1_ex2 = counter_1_ex2 + 1
    value = ex2_answer.value
    correct_value = fn.verify_ex2(n_aromes, agencements)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_1_ex2))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Vous pouvez resoumettre une autre réponse ou procéder étape par étape en cliquant sur 'Show Solution'".format(counter_1_ex2))


display(widgets.HBox([ex2_answer, button]))

button.on_click(test_0_ex2)

#print(fn.verify_ex2())
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Nous devons décomposer le problème en sous parties. \n \
On commence par se demander combien de possibilités il y a pour chaque type d'agencement: à 1 boule, à 2 boules ou à 3 boules. \n \
Par la suite, on combine les possibilités de tous les agencements. \n")

print("Avec 10 arômes, combien de possibilités différentes de glaces à 1 boule pourrons-nous former?")

counter_2_ex2 = 0

ex2q1_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)


def test_1_ex2(change):
    global counter_2_ex2 
    counter_2_ex2 = counter_2_ex2 + 1
    value = ex2q1_answer.value
    correct_value = fn.verify_ex2(n_aromes, [1])
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_2_ex2))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        N'oubliez pas, on ne veut pas de répétitions dans les aromes! ;)".format(counter_2_ex2))


display(widgets.HBox([ex2q1_answer, button]))

button.on_click(test_1_ex2)
# Out:
# Nous devons décomposer le problème en sous parties.
#  On commence par se demander combien de possibilités il y a pour chaque type d'agencement: à 1 boule, à 2 boules ou à 3 boules.
#  Par la suite, on combine les possibilités de tous les agencements.
#
# Avec 10 arômes, combien de possibilités différentes de glaces à 1 boule pourrons-nous former?
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Avec 10 arômes, combien de possibilités différentes de glaces à 2 boules pourrons-nous former? \n")
print("Attention: de nouveau, on ne veut pas des répétitions dans les arômes dans la même glace! \n \
Pas deux boules de chocolat ensemble par exemple, mais 1 boule chocolat et une boule pistache ;)")

counter_3_ex2 = 0

ex2q2_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='',
    tooltip='Click me',
    icon='check' 
)


def test_3_ex2(change):
    global counter_3_ex2 
    counter_3_ex2 = counter_3_ex2 + 1
    value = ex2q2_answer.value
    correct_value = fn.verify_ex2(n_aromes, [2])
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :) \n\
        Une illustration est disponible ci-dessous".format(counter_3_ex2))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Regardez l'ilustration ci-dessous pour vous inspirer ;)".format(counter_3_ex2))


display(widgets.HBox([ex2q2_answer, button]))

button.on_click(test_3_ex2)
# Out:
# Avec 10 arômes, combien de possibilités différentes de glaces à 2 boules pourrons-nous former?
#
# Attention: de nouveau, on ne veut pas des répétitions dans les arômes dans la même glace!
#  Pas deux boules de chocolat ensemble par exemple, mais 1 boule chocolat et une boule pistache ;)
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
Image("img/ex2_boules.png")

# %%
print("Avec 10 arômes, combien de possibilités différentes de glaces à 3 boules pourrons-nous former? \n")

counter_4_ex2 = 0

ex2q3_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='',
    tooltip='Click me',
    icon='check' 
)


def test_4_ex2(change):
    global counter_4_ex2 
    counter_4_ex2 = counter_4_ex2 + 1
    value = ex2q3_answer.value
    correct_value = fn.verify_ex2(n_aromes, [3])
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_4_ex2))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Consultez à nouveau la solution pour l'agencement à 2 boules et ajouter une étape ;)".format(counter_4_ex2))


display(widgets.HBox([ex2q3_answer, button]))

button.on_click(test_4_ex2)
# Out:
# Avec 10 arômes, combien de possibilités différentes de glaces à 3 boules pourrons-nous former?
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Ultérieurement, nous avons vu comment compter les possibilités des glaces si on connait le type d'agencement souhaité. \n")
print("Maintenant, on doit se demander sur le nombre total de possibilités de glaces, \n \
ne sachant pas à l'avance l'agencement spécifique qui pourra être demandé.")

print("Il nous faut maintenant combiner les résultats déjà trouvés. \n")
print("Une personne qui vient acheter une seule glace, choisit une glace à 1 boule OU 2 boules OU 3 boules.")

print("Quel principe faudra-t-il appliquer ici pour combiner les possibilités de toutes les glaces?")

def test_5_ex2(change):
    global counter_5_ex2
    counter_5_ex2 = counter_5_ex2 + 1
    value = drop_ex2.value
    correct_value = 'addition'
    if value == correct_value:
        print("Tentative {} : Exact! Nous devons procéder à additionner les possibilités pour tous les agencements. \n \
        Revenez au début de l'exercice et resoumettez votre réponse. \n \
        Une illustration ci-dessous".format(counter_5_ex2))
    else:

        print("Tentative {}: Non, ce n'est pas tout à fait correct. \n \
        Regardez l'exemple dfans l'illustration ci-dessous.".format(counter_5_ex2))

counter_5_ex2 = 0
drop_ex2 = widgets.Dropdown(
    options=['aucune', 'addition', 'multiplication', 'les deux'],
    value='aucune',
    description='Principe de:',
    disabled=False,
)

button_comb = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)

display(widgets.HBox([drop_ex2, button_comb]))

out3 = widgets.Output(layout={'border': '1px solid black'})

with out3:
    button_comb.on_click(test_5_ex2)
out3
# Out:
# Ultérieurement, nous avons vu comment compter les possibilités des glaces si on connait le type d'agencement souhaité.
#
# Maintenant, on doit se demander sur le nombre total de possibilités de glaces,
#  ne sachant pas à l'avance l'agencement spécifique qui pourra être demandé.
# Il nous faut maintenant combiner les résultats déjà trouvés.
#
# Une personne qui vient acheter une seule glace, choisit une glace à 1 boule OU 2 boules OU 3 boules.
# Quel principe faudra-t-il appliquer ici pour combiner les possibilités de toutes les glaces?
# HBox(children=(Dropdown(description='Principe de:', options=('aucune', 'addition', 'multiplication', 'les deux…
# Output(layout=Layout(border='1px solid black'))

# %%
Image("img/ex2_boules_2.png")

# %% [markdown]
# # Exercice 3
#
# Combien peut-on former de nombres naturels, **ne commençant pas par 0**, ... :

# %% [markdown]
# ## de 4 chiffres différents ?

# %%
counter_1_ex3 = 0

ex3_q1_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='',
    tooltip='Click me',
    icon='check' 
)


def test_1_ex3(change):
    global counter_1_ex3 
    counter_1_ex3 = counter_1_ex3 + 1
    value = ex3_q1_answer.value
    correct_value = fn.verify_ex3_1()
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_1_ex3))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Une décomposition visuelle est à votre disposition en cliquant sur 'Show Solutions' \n \
        Attention à comment combiner les possibilités!!".format(counter_1_ex3))


display(widgets.HBox([ex3_q1_answer, button]))

button.on_click(test_1_ex3)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
Image("img/ex3_1.png")

# %%
Image("img/ex3_exsimplifie.png")

# %% [markdown]
# ## de 4 chiffres différents qui ne contiennent pas le chiffre 5 ?

# %%
counter_2_ex3 = 0

ex3_q2_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='',
    tooltip='Click me',
    icon='check' 
)


def test_2_ex3(change):
    global counter_2_ex3 
    counter_2_ex3 = counter_2_ex3 + 1
    value = ex3_q2_answer.value
    correct_value = fn.verify_ex3_2()
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_2_ex3))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Une décomposition visuelle est à votre disposition en cliquant sur 'Show Solution' \n \
        Attention à comment combiner les possibilités!!".format(counter_2_ex3))


display(widgets.HBox([ex3_q2_answer, button]))

button.on_click(test_2_ex3)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
Image("img/ex3_2.png")

# %% [markdown]
# ## de 4 chiffres différents si ces nombres doivent être divisibles par 5 ?

# %%
counter_3_ex3 = 0

ex3_q3_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)


def test_3_ex3(change):
    global counter_3_ex3 
    counter_3_ex3 = counter_3_ex3 + 1
    value = ex3_q3_answer.value
    correct_value = fn.verify_ex3_3()
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_3_ex3))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Une décomposition visuelle est à votre disposition en cliquant sur 'Show Solution' \n \
        Attention à comment combiner les possibilités!!".format(counter_3_ex3))


display(widgets.HBox([ex3_q3_answer, button]))

button.on_click(test_3_ex3)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
Image("img/ex3_3_1.png")

# %%
Image("img/ex3_3_2.png")

# %%
Image("img/ex3_3_3.png")

# %% [markdown]
# ## compris entre 100 et 100'000 commençant par un chiffre impair et contenant des chiffres différents ?

# %%
counter_4_ex3 = 0

ex3_q4_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_4_ex3(change):
    global counter_4_ex3 
    counter_4_ex3 = counter_4_ex3 + 1
    value = ex3_q4_answer.value
    correct_value = fn.verify_ex3_4()
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_4_ex3))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Une décomposition visuelle est à votre disposition en cliquant sur 'Show Solution' \n \
        Attention à comment combiner les possibilités!!".format(counter_4_ex3))


display(widgets.HBox([ex3_q4_answer, button]))

button.on_click(test_4_ex3)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
Image("img/ex3_4_1.png")

# %%
Image("img/ex3_4_2.png")

# %%
print("N'oubliez pas de combiner le tout comme s'ils sont mélangés dans la même urne !!! \n")
print("Revenez au début de l'exercice pour resoumettre votre réponse.")
# Out:
# N'oubliez pas de combiner le tout comme s'ils sont mélangés dans la même urne !!!
#
# Revenez au début de l'exercice pour resoumettre votre réponse.

# %% [markdown]
# # Exercice 4
#
# Simplifier les expressions suivantes:
#
# 1) $\frac{100!}{98!}$
#
# 2) $1000 . 999!$
#
# 3) $\frac{(n-1)!}{(n-3)!}$

# %% [markdown]
# 1) $\frac{100!}{98!} = \frac{100 . 99 . 98!}{98!} = 100 . 99 = 9900$. On simplifie $98!$ du numérateur et du dénominateur.
#
# 2) $1000. 999! = 1000! \approx \sqrt{2000\pi}.\large(\frac{1000}{e}\large)^{1000}$ C'est un très grand chiffre, il doit être approximé en pratique.
#
# 3) $\frac{(n-1)!}{(n-3)!} = \frac{(n-1)(n-2)(n-3)!}{(n-3)!} = (n-1)(n-2) = n^2 -2n -n + 2 = n^2 -3n + 2$

# %% [markdown]
# # Exercice 5
#
# On dispose des symboles suivants: $\{A, B, C, 1, 2, 3, 4, 5\}$. Nous voulons déterminer le nombre de plaques de véhicules que nous pourrons identifiés avec les systèmes d'immatriculation suivants:

# %% [markdown]
# ## Chaque plaque comprend 6 symboles choisis uniquement parmi les chiffres.

# %%
n_1_ex5 = 6 
n_choice_1_ex5 = 5

counter_1_ex5 = 0

ex5_q1_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_1_ex5(change):
    global counter_1_ex5 
    counter_1_ex5 = counter_1_ex5 + 1
    value = ex5_q1_answer.value
    correct_value = fn.verify_ex5_1(n_1_ex5, n_choice_1_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_1_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Cliquez sur 'Show Solution' pour quelques indices...".format(counter_1_ex5))


display(widgets.HBox([ex5_q1_answer, button]))

button.on_click(test_1_ex5)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Chaque plaque est une série de 6 valeurs à choisir : _ _ _ _ _ _  \n ")
# Out:
# Chaque plaque est une série de 6 valeurs à choisir : _ _ _ _ _ _

# %%
print("Combien de chiffres y-a-t-il parmis les smyboles? \n ")

user_n_choice_1_1_ex5 = widgets.Dropdown(
    options=['6', '5', '3', '0'],
    value='0',
    description='Réponse:',
    disabled=False,
)

def on_change_1_1_ex5(change):
    global n_choice_1_ex5
    if int(change['new']) == n_choice_1_ex5:
        print('Votre réponse {} est correcte!'.format(int(change['new'])))
    else:
        print("Votre réponse {} n'est pas correcte!! \n \
        Nous avons 6 symboles au total 𝐴,𝐵,𝐶,1,2,3,4,5 qui contiennent 5 chiffres: 1, 2, 3, 4, 5. ".format(int(change['new'])))
    
display(user_n_choice_1_1_ex5)
user_n_choice_1_1_ex5.observe(on_change_1_1_ex5, names = 'value')
# Out:
# Combien de chiffres y-a-t-il parmis les smyboles?
# Dropdown(description='Réponse:', index=3, options=('6', '5', '3', '0'), value='0')

# %%
print("Si on ne considère que les chiffres parmis les symboles, et on accepte les répétitions, \n \
combien de possibilités y-a-t-il pour remplir chacune des valeurs dans la plaque?\n")

user_n_choice_1_2_ex5 = widgets.Dropdown(
    options=['6', '5', '3', '0'],
    value='0',
    description='Réponse:',
    disabled=False,
)

def on_change_1_2_ex5(change):
    global n_choice_1_ex5
    if int(change['new']) == n_choice_1_ex5:
        print('Votre réponse {} est correcte!'.format(int(change['new'])))
    else:
        print("Votre réponse {} n'est pas correcte!!\n \
        Nous avons 6 symboles au total 𝐴,𝐵,𝐶,1,2,3,4,5 qui contiennent 5 chiffres: 1, 2, 3, 4, 5. ".format(int(change['new'])))
    
display(user_n_choice_1_2_ex5)
user_n_choice_1_2_ex5.observe(on_change_1_2_ex5, names = 'value')
# Out:
# Si on ne considère que les chiffres parmis les symboles, et on accepte les répétitions,
#  combien de possibilités y-a-t-il pour remplir chacune des valeurs dans la plaque?
# Dropdown(description='Réponse:', index=3, options=('6', '5', '3', '0'), value='0')

# %%
print("Quelle règle nous permet de combiner les possibilités des 6 valeurs?")

user_n_choice_1_3_ex5 = widgets.Dropdown(
    options=['logarithmique', 'addition', 'multiplication', 'aucune'],
    value='aucune',
    description='Réponse:',
    disabled=False,
)

def on_change_1_3_ex5(change):
    global n_choice
    if change['new'] == 'multiplication':
        print("Votre réponse '{}' est correcte!".format(change['new']))
    else:
        print("Votre réponse '{}' n'est pas correcte!! Dessinez un arbre pour un problèm réduit: \n \
        seulement deux valeurs et 3 symboles possibles. Combien de possibilités y-a-t-il au total? \n \
        Quelle règle avez-vous utilisé pour combiner les possibilités des deux valeurs?".format(change['new']))
    
display(user_n_choice_1_3_ex5)
user_n_choice_1_3_ex5.observe(on_change_1_3_ex5, names = 'value')
# Out:
# Quelle règle nous permet de combiner les possibilités des 6 valeurs?
# Dropdown(description='Réponse:', index=3, options=('logarithmique', 'addition', 'multiplication', 'aucune'), v…

# %%
print("Revenez au début de l'exercice pour resoumettre votre réponse!")
# Out:
# Revenez au début de l'exercice pour resoumettre votre réponse!

# %% [markdown]
# ## Chaque plaque comprend 6 symboles dont 1 lettre suivie de 5 chiffres.

# %%
n_num_2_ex5 = 5 
n_let_2_ex5 = 1
n_choice_num_2_ex5 = 5
n_choice_let_2_ex5 = 3


counter_2_ex5 = 0

ex5_q2_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_2_ex5(change):
    global counter_2_ex5 
    counter_2_ex5 = counter_2_ex5 + 1
    value = ex5_q2_answer.value
    correct_value = fn.verify_ex5_2(n_num_2_ex5, n_choice_num_2_ex5, n_let_2_ex5, n_choice_let_2_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_2_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Cliquez sur 'Show Solution' pour quelques indices...".format(counter_2_ex5))


display(widgets.HBox([ex5_q2_answer, button]))

button.on_click(test_2_ex5)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Il y a une lettre, mais sa place est fixe, en première position.\n \
Mais combien de possiblités y-a-t-il pour remplir cette position?")

user_n_choice_2_1_ex5 = widgets.Dropdown(
    options=['6', '5', '3', '0'],
    value='0',
    description='Réponse:',
    disabled=False,
)

def on_change_2_1_ex5(change):
    global n_choice_let_2_ex5
    if int(change['new']) == n_choice_let_2_ex5:
        print('Votre réponse {} est correcte!'.format(int(change['new'])))
    else:
        print("Votre réponse {} n'est pas correcte!! Nous avons 6 symboles au total 𝐴,𝐵,𝐶,1,2,3,4,5 qui contiennent 3 lettres: A, B, C. ".format(int(change['new'])))
    
display(user_n_choice_2_1_ex5)
user_n_choice_2_1_ex5.observe(on_change_2_1_ex5, names = 'value')
# Out:
# Il y a une lettre, mais sa place est fixe, en première position.
#  Mais combien de possiblités y-a-t-il pour remplir cette position?
# Dropdown(description='Réponse:', index=3, options=('6', '5', '3', '0'), value='0')

# %%
print("Il reste donc 5 positions à remplir avec les chiffres. \n \
En acceptant les répétitions, combien de possibilités y-a-t-il pour remplir les 5 cases avec les 5 chiffres à disoposition?")

n_num_2_2_ex5 = 5 
n_choice_2_2_ex5 = 5

counter_3_ex5 = 0

ex5_q1_answer_2 = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' # 
)


def test_2_2_ex5(change):
    global counter_3_ex5 
    counter_3_ex5 = counter_3_ex5 + 1
    value = ex5_q1_answer_2.value
    correct_value = fn.verify_ex5_1(n_num_2_2_ex5, n_choice_2_2_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_3_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Combien de possibilités y-a-t-il pour remplir chaque position? comment combiner les possibilités pour les 5 cases? ".format(counter_3_ex5))


display(widgets.HBox([ex5_q1_answer_2, button]))

button.on_click(test_2_2_ex5)
# Out:
# Il reste donc 5 positions à remplir avec les chiffres.
#  En acceptant les répétitions, combien de possibilités y-a-t-il pour remplir les 5 cases avec les 5 chiffres à disoposition?
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Comment combiner les possibilités de la lettre et les possibilités des 5 chiffres?")

user_n_choice_2_3_ex5 = widgets.Dropdown(
    options=['logarithmique', 'addition', 'multiplication', 'aucune'],
    value='aucune',
    description='Réponse:',
    disabled=False,
)

def on_change_2_3_ex5(change):
    global n_choice
    if change['new'] == 'multiplication':
        print("Votre réponse '{}' est correcte!".format(change['new']))
    else:
        print("Votre réponse '{}' n'est pas correcte!! hint: Dessinez un arbre pour un problèm réduit. \n \
        Combien de possibilités y-a-t-il au total? \n \
        Quelle règle vous avez utilisez pour combiner les possibilités?".format(change['new']))
    
display(user_n_choice_2_3_ex5)
user_n_choice_2_3_ex5.observe(on_change_2_3_ex5, names = 'value')
# Out:
# Comment combiner les possibilités de la lettre et les possibilités des 5 chiffres?
# Dropdown(description='Réponse:', index=3, options=('logarithmique', 'addition', 'multiplication', 'aucune'), v…

# %%
print("Revenez au début de l'exercice pour resoumettre votre réponse!")
# Out:
# Revenez au début de l'exercice pour resoumettre votre réponse!

# %% [markdown]
# ## Chaque plaque comprend 6 symboles dont 1 lettre et 5 chiffres.

# %%
total_pos = 6
n_num_3_ex5 = 5 
n_let_3_ex5 = 1
n_choice_num_3_ex5 = 5
n_choice_let_3_ex5 = 3


counter_3_ex5 = 0

ex5_q3_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_3_ex5(change):
    global counter_3_ex5 
    counter_3_ex5 = counter_3_ex5 + 1
    value = ex5_q3_answer.value
    correct_value = fn.verify_ex5_3(total_pos, n_num_3_ex5, n_choice_num_3_ex5, n_let_3_ex5, n_choice_let_3_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_3_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Cliquez sur 'Show Solution' pour quelques indices...".format(counter_3_ex5))


display(widgets.HBox([ex5_q3_answer, button]))

button.on_click(test_3_ex5)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("Par rapport à la question précédente, on ne connait pas ici la position de la lettre.")
print("Combien y-a-t-il de positions possibles pour la lettre?")


user_n_choice_3_1_ex5 = widgets.Dropdown(
    options=['6', '5', '3', '0'],
    value='0',
    description='Réponse:',
    disabled=False,
)

def on_change_3_1_ex5(change):
    global n_choice_let_3_ex5
    if int(change['new']) == total_pos:
        print('Votre réponse {} est correcte!'.format(int(change['new'])))
    else:
        print("Votre réponse {} n'est pas correcte!! La lettre pourra apparaitre dans la 1ere, 2eme, 3eme, 4eme, 5eme OU 6eme position.".format(int(change['new'])))
    
display(user_n_choice_3_1_ex5)
user_n_choice_3_1_ex5.observe(on_change_3_1_ex5, names = 'value')
# Out:
# Par rapport à la question précédente, on ne connait pas ici la position de la lettre.
# Combien y-a-t-il de positions possibles pour la lettre?
# Dropdown(description='Réponse:', index=3, options=('6', '5', '3', '0'), value='0')

# %%
print("Une fois on prend en compte la position de la lettre, \n \
nous devons prendre en compte les possibilités de remplir cette position.")
print("Comme pour la question précédente, nous avons 3 symboles: A, B, C, pour choisir la lettre.")
print("Comme pour la question précédente, nous avons 5 symboles: 1, 2, 3, 4, 5, pour choisir les chiffres restants.")
print("Comment devons nous combiner ces possibilités? Encore en doute? jetez un coup d'oeil sur l'illustration mise à disposition.")
print("Revenez au début de la question pour resoumettre votre réponse.")
# Out:
# Une fois on prend en compte la position de la lettre,
#  nous devons prendre en compte les possibilités de remplir cette position.
# Comme pour la question précédente, nous avons 3 symboles: A, B, C, pour choisir la lettre.
# Comme pour la question précédente, nous avons 5 symboles: 1, 2, 3, 4, 5, pour choisir les chiffres restants.
# Comment devons nous combiner ces possibilités? Encore en doute? jetez un coup d'oeil sur l'illustration mise à disposition.
# Revenez au début de la question pour resoumettre votre réponse.

# %%
Image("img/ex5_3.png")

# %% [markdown]
# ## Chaque plaque commence par 2 lettres suivies d’au maximum 4 chiffres.

# %%
n_num_4_ex5 = 4
n_let_4_ex5 = 2
n_choice_num_4_ex5 = 5
n_choice_let_4_ex5 = 3


counter_4_ex5 = 0

ex5_q4_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_4_ex5(change):
    global counter_4_ex5 
    counter_4_ex5 = counter_4_ex5 + 1
    value = ex5_q4_answer.value
    correct_value = fn.verify_ex5_4(n_num_4_ex5, n_choice_num_4_ex5, n_let_4_ex5, n_choice_let_4_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_4_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Cliquez sur 'Show Solution' pour quelques indices...".format(counter_4_ex5))


display(widgets.HBox([ex5_q4_answer, button]))

button.on_click(test_4_ex5)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("En lisant la question, on déduit que les deux premières positions dans les plaques sont réservées aux lettres.")

print("Combien de positions dans les plaques sont réservées aux chiffres? \n \
        (Vous pouvez séléctionner simultanément plusieurs valeurs en cliquant \n \
      le boutton 'Ctrl' en même temps que vous cliquez sur les valeurs.)")

user_n_choice_4_1_ex5 = widgets.SelectMultiple(
    options=['0', '1', '2', '3', '4', '5', '6'],
    #value=['4'],
    description='Réponse',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def on_change_4_1_ex5(change):
    if list(user_n_choice_4_1_ex5.value) == ['0', '1', '2', '3', '4']:
        print('Votre réponse est correcte!')
    else:
        print("Votre réponse n'est pas correcte! \n \
        Les 2 lettres sont suivies d’au MAXIMUM 4 chiffres, ça peut être 0, 1, 2, 3 ou 4 chiffres.")
        
display(widgets.HBox([user_n_choice_4_1_ex5, button]))

button.on_click(on_change_4_1_ex5)
# Out:
# En lisant la question, on déduit que les deux premières positions dans les plaques sont réservées aux lettres.
# Combien de positions dans les plaques sont réservées aux chiffres?
#          (Vous pouvez séléctionner simultanément plusieurs valeurs en cliquant
#        le boutton 'Ctrl' en même temps que vous cliquez sur les valeurs.)
# HBox(children=(SelectMultiple(description='Réponse', options=('0', '1', '2', '3', '4', '5', '6'), value=()), B…

# %%
print("Il s'agit maintenant de compter les possibilités dans chaque cas pour les combiner par la suite. \n")

print("De combien de manière pourrons-nous choisir les 2 lettres?")

print("Pour chaque séléction du nombre de positions pour les chiffres, donnez le total des possibilités \n \
pour séléctionner les chiffres!")

ex5_q4_let_answer = widgets.IntText(
    value= 0,
    disabled=False, 
    layout = {'width': '300px'}
   
)
hbox_ex5_q4_let_answer = widgets.HBox([widgets.Label('Total des possibilités pour choisir les 2 lettres:'), ex5_q4_let_answer])

ex5_q4_num_n_answer = widgets.Dropdown(
    options=['0', '1', '2', '3', '4', '5', '6'],
    disabled=False,
    layout = {'width': '300px'}
)

hbox_ex5_q4_num_n_answer =  widgets.HBox([widgets.Label('Nombre de positions pour les chiffres:'), ex5_q4_num_n_answer])

ex5_q4_num_total_answer = widgets.IntText(
    disabled=False,
    layout = {'width': '300px'}
)

hbox_ex5_q4_num_total_answer = widgets.HBox([widgets.Label('Total des possibilités pour choisir les chiffres:'), ex5_q4_num_total_answer])


button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)

let_flag = False 
num_total_flag = False
num_flag = False

def on_change_4_2_ex5(change):
    global ex5_q4_num_n_answer
    global let_flag
    global num_total_flag
    global num_flag
    global out_ex5_q4
    
    
    
    if int(ex5_q4_let_answer.value) == fn.count_with_rep(n_let_4_ex5, n_choice_let_4_ex5):
        let_flag = True 
    else:
        let_flag = False
    
    if int(ex5_q4_num_n_answer.value) <= 4:
        num_flag = True
        if ex5_q4_num_total_answer.value == fn.count_with_rep(int(ex5_q4_num_n_answer.value), n_choice_num_4_ex5):
            num_total_flag = True
        else:
            num_total_flag = False
    else:
        num_flag = False
    
    if let_flag and num_total_flag and num_flag:

        print('---------------------------')
        print('Vos réponses sont correctes!')
    else:
        
           
        print('---------------------------')
        print("Votre réponse n'est pas correcte! \n")
        if not let_flag:
            print("Vous vous êtes trompés avec le total des possibilités des 2 lettres. \n \
            En acceptant les répétitions, de combien de manières pourrons nous choisir 2 lettres ayant 3 possibilité chacune?")
        if not num_flag:
            print("Vous vous êtes trompés avec le nombre de positions des chiffres. \n \
                  Le nombre de position des chiffres doit être au maximum égal à 4.")
        if not num_total_flag:
            print("Vous vous êtes trompés avec le total des possibilités des chiffres. \n \
            En acceptant les répétitions, de combien de manières pourrons nous choisir {} chiffres ayant 5 possibilités chacun?".format(int(ex5_q4_num_n_answer.value)))


button.on_click(on_change_4_2_ex5)
        

display(widgets.VBox([hbox_ex5_q4_let_answer, hbox_ex5_q4_num_n_answer, hbox_ex5_q4_num_total_answer , button]))
# Out:
# Il s'agit maintenant de compter les possibilités dans chaque cas pour les combiner par la suite.
#
# De combien de manière pourrons-nous choisir les 2 lettres?
# Pour chaque séléction du nombre de positions pour les chiffres, donnez le total des possibilités
#  pour séléctionner les chiffres!
# VBox(children=(HBox(children=(Label(value='Total des possibilités pour choisir les 2 lettres:'), IntText(value…

# %%
print("Dans l'étape précédente, vous avez généré plusieurs scenarios de plaques, avec 0 ou plusieurs chiffres.")
print("Dans chacun des scenarios, selon quelle règle faudra-t-il combiner toutes les possibilités des 2 lettres avec les possibililtés des chiffres?")

user_n_choice_4_2_ex5 = widgets.Dropdown(
    options=['logarithmique', 'addition', 'multiplication', 'aucune'],
    value='aucune',
    description='Réponse:',
    disabled=False,
)

def on_change_4_2_ex5(change):
    global n_choice
    if change['new'] == 'multiplication':
        print("Votre réponse '{}' est correcte!".format(change['new']))
    else:
        print("Votre réponse '{}' n'est pas correcte!! \n \
        hint: dessinez un arbre pour un cas simplifié".format(change['new']))
    
display(user_n_choice_4_2_ex5)
user_n_choice_4_2_ex5.observe(on_change_4_2_ex5, names = 'value')
# Out:
# Dans l'étape précédente, vous avez généré plusieurs scenarios de plaques, avec 0 ou plusieurs chiffres.
# Dans chacun des scenarios, selon quelle règle faudra-t-il combiner toutes les possibilités des 2 lettres avec les possibililtés des chiffres?
# Dropdown(description='Réponse:', index=3, options=('logarithmique', 'addition', 'multiplication', 'aucune'), v…

# %%
print("A ce stade vous avez compté les possibilités de construire les plaques selon différents scenarios.")
print("Selon quelle règle faudra-t-il combiner toutes les possibilités?")

user_n_choice_4_3_ex5 = widgets.Dropdown(
    options=['logarithmique', 'addition', 'multiplication', 'aucune'],
    value='aucune',
    description='Réponse:',
    disabled=False,
)

def on_change_4_3_ex5(change):
    global n_choice
    if change['new'] == 'addition':
        print("Votre réponse '{}' est correcte!".format(change['new']))
    else:
        print("Votre réponse '{}' n'est pas correcte!! \n \
        hint: imaginez que l'on mette toutes les possibilités ensemble dans une urne".format(change['new']))
    
display(user_n_choice_4_3_ex5)
user_n_choice_4_3_ex5.observe(on_change_4_3_ex5, names = 'value')
# Out:
# A ce stade vous avez compté les possibilités de construire les plaques selon différents scenarios.
# Selon quelle règle faudra-t-il combiner toutes les possibilités?
# Dropdown(description='Réponse:', index=3, options=('logarithmique', 'addition', 'multiplication', 'aucune'), v…

# %%
print("Revenez au début de la question pour resoumettre votre réponse.")
# Out:
# Revenez au début de la question pour resoumettre votre réponse.

# %% [markdown]
# ## Chaque plaque comprend 6 symboles dont 2 lettres et 4 chiffres.

# %%
pos_tot = 6
n_num_5_ex5 = 4
n_let_5_ex5 = 2
n_choice_num_5_ex5 = 5
n_choice_let_5_ex5 = 3


counter_5_ex5 = 0

ex5_q5_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_5_ex5(change):
    global counter_5_ex5 
    counter_5_ex5 = counter_5_ex5 + 1
    value = ex5_q5_answer.value
    correct_value = fn.verify_ex5_5(pos_tot, n_num_5_ex5, n_choice_num_5_ex5, n_let_5_ex5, n_choice_let_5_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_5_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        Cliquez sur 'Show Solution' pour quelques indices...".format(counter_5_ex5))


display(widgets.HBox([ex5_q5_answer, button]))

button.on_click(test_5_ex5)
# Out:
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("A la différence de la question précédente, dans cette question on ne fixe pas la position des 2 lettres à l'avance. \n")
print("Rappelez-vous que si on fixe les positions des lettres, on fixe aussi la position des chiffres. \n \
Donc il suffit de regarder l'un ou l'autre et non pas les deux, pour ne pas compter à double. \n")
print("De combien de manières différentes pourrons-nous placer les 2 lettres?")

counter_1_5_ex5 = 0

ex5_q5_1_answer = widgets.IntText(
    value= 0,
    description='Réponse:',
    disabled=False
)

button = widgets.Button(
    description='Soumettre',
    disabled=False,
    button_style='', 
    tooltip='Click me',
    icon='check' 
)


def test_1_4_ex5(change):
    global counter_1_5_ex5 
    counter_1_5_ex5 = counter_1_5_ex5 + 1
    value = ex5_q5_1_answer.value
    correct_value = fn.nCr(pos_tot,n_let_5_ex5)
    if value == correct_value:
        print("Tetantive {}: Bravo! votre réponse est correcte :)".format(counter_1_5_ex5))
    else:
        print("Tetantive {}:Malheureusement, la réponse soumise n'est pas correcte. \n \
        hint: comment choisir 2 positions parmi 6?".format(counter_1_5_ex5))


display(widgets.HBox([ex5_q5_1_answer, button]))

button.on_click(test_1_4_ex5)
# Out:
# A la différence de la question précédente, dans cette question on ne fixe pas la position des 2 lettres à l'avance.
#
# Rappelez-vous que si on fixe les positions des lettres, on fixe aussi la position des chiffres.
#  Donc il suffit de regarder l'un ou l'autre et non pas les deux, pour ne pas compter à double.
#
# De combien de manières différentes pourrons-nous placer les 2 lettres?
# HBox(children=(IntText(value=0, description='Réponse:'), Button(description='Soumettre', icon='check', style=B…

# %%
print("A ce stade on compte le total des possibilités pour choisir les 2 lettres et le total des possibilités pour choisir \
les 4 chiffres comme nous l'avons fait dans la question précédente. \n")
print("Chaque positionnement des lettres nous donne un scenario. ")
print("Pour chacun des scenario, on se rappelle de combiner le total des possibilités des lettres et ceux des chiffres avec la règle de:")

user_n_choice_5_2_ex5 = widgets.Dropdown(
    options=['logarithmique', 'addition', 'multiplication', 'aucune'],
    value='aucune',
    description='Réponse:',
    disabled=False,
)

def on_change_5_2_ex5(change):
    global n_choice
    if change['new'] == 'multiplication':
        print("Votre réponse '{}' est correcte!".format(change['new']))
    else:
        print("Votre réponse '{}' n'est pas correcte!! \n \
         hint: dessinez un arbre pour un cas simplifié".format(change['new']))
    
display(user_n_choice_5_2_ex5)
user_n_choice_5_2_ex5.observe(on_change_5_2_ex5, names = 'value')
# Out:
# A ce stade on compte le total des possibilités pour choisir les 2 lettres et le total des possibilités pour choisir les 4 chiffres comme nous l'avons fait dans la question précédente.
#
# Chaque positionnement des lettres nous donne un scenario.
# Pour chacun des scenario, on se rappelle de combiner le total des possibilités des lettres et ceux des chiffres avec la règle de:
# Dropdown(description='Réponse:', index=3, options=('logarithmique', 'addition', 'multiplication', 'aucune'), v…

# %%
print("A ce stade vous avez compté les possibilités de construire les plaques selon différents positionnement des lettres.")
print("Selon quelle règle faudra-t-il combiner toutes les possibilités?")

user_n_choice_5_3_ex5 = widgets.Dropdown(
    options=['logarithmique', 'addition', 'multiplication', 'aucune'],
    value='aucune',
    description='Réponse:',
    disabled=False,
)

def on_change_5_3_ex5(change):
    global n_choice
    if change['new'] == 'addition':
        print("Votre réponse '{}' est correcte!".format(change['new']))
    else:
        print("Votre réponse '{}' n'est pas correcte!! \n \
        hint: imaginez que l'on mette toutes les possibilités ensemble dans une urne".format(change['new']))
    
display(user_n_choice_5_3_ex5)
user_n_choice_5_3_ex5.observe(on_change_5_3_ex5, names = 'value')
# Out:
# A ce stade vous avez compté les possibilités de construire les plaques selon différents positionnement des lettres.
# Selon quelle règle faudra-t-il combiner toutes les possibilités?
# Dropdown(description='Réponse:', index=3, options=('logarithmique', 'addition', 'multiplication', 'aucune'), v…

# %%
print("Revenez au début de la question pour resoumettre votre réponse.")
# Out:
# Revenez au début de la question pour resoumettre votre réponse.
